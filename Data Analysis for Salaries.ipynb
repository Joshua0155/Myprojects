# %%
import os
import numpy as np
import pandas as pd

data = pd.read_csv("ds_salaries.csv")

# %%
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
data.tail(10)
# Out:
#       work_year experience_level employment_type  \
# 3745       2021               SE              FT
# 3746       2021               MI              FT
# 3747       2021               MI              FT
# 3748       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3751       2021               MI              FT
# 3752       2020               EN              FT
# 3753       2020               EN              CT
# 3754       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 3745            Director of Data Science   168000             USD
# 3746                      Data Scientist   160000             SGD
# 3747  Applied Machine Learning Scientist   423000             USD
# 3748                       Data Engineer    24000             EUR
# 3749                     Data Specialist   165000             USD
# ...

# %%
data.shape
data.index
# Out:
# RangeIndex(start=0, stop=3755, step=1)

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
data.dtypes
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
data["salary_currency"].nunique()
# Out:
# 20

# %%
data.nunique()
# Out:
# work_year                4
# experience_level         4
# employment_type          4
# job_title               93
# salary                 815
# salary_currency         20
# salary_in_usd         1035
# employee_residence      78
# remote_ratio             3
# company_location        72
# company_size             3
# dtype: int64

# %%
data.count()
# Out:
# work_year             3755
# experience_level      3755
# employment_type       3755
# job_title             3755
# salary                3755
# salary_currency       3755
# salary_in_usd         3755
# employee_residence    3755
# remote_ratio          3755
# company_location      3755
# company_size          3755
# dtype: int64

# %%
data['job_title'].count()
# Out:
# 3755

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3755 entries, 0 to 3754
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           3755 non-null   int64
#  1   experience_level    3755 non-null   object
#  2   employment_type     3755 non-null   object
#  3   job_title           3755 non-null   object
#  4   salary              3755 non-null   int64
#  5   salary_currency     3755 non-null   object
#  6   salary_in_usd       3755 non-null   int64
#  7   employee_residence  3755 non-null   object
#  8   remote_ratio        3755 non-null   int64
#  9   company_location    3755 non-null   object
#  10  company_size        3755 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 322.8+ KB

# %%
data["job_title"].unique()
# Out:
# array(['Principal Data Scientist', 'ML Engineer', 'Data Scientist',
#        'Applied Scientist', 'Data Analyst', 'Data Modeler',
#        'Research Engineer', 'Analytics Engineer',
#        'Business Intelligence Engineer', 'Machine Learning Engineer',
#        'Data Strategist', 'Data Engineer', 'Computer Vision Engineer',
#        'Data Quality Analyst', 'Compliance Data Analyst',
#        'Data Architect', 'Applied Machine Learning Engineer',
#        'AI Developer', 'Research Scientist', 'Data Analytics Manager',
#        'Business Data Analyst', 'Applied Data Scientist',
#        'Staff Data Analyst', 'ETL Engineer', 'Data DevOps Engineer',
#        'Head of Data', 'Data Science Manager', 'Data Manager',
#        'Machine Learning Researcher', 'Big Data Engineer',
#        'Data Specialist', 'Lead Data Analyst', 'BI Data Engineer',
#        'Director of Data Science', 'Machine Learning Scientist',
#        'MLOps Engineer', 'AI Scientist', 'Autonomous Vehicle Technician',
# ...

# %%
data.job_title.value_counts()
# Out:
# Data Engineer                          1040
# Data Scientist                          840
# Data Analyst                            612
# Machine Learning Engineer               289
# Analytics Engineer                      103
#                                        ...
# Principal Machine Learning Engineer       1
# Azure Data Engineer                       1
# Manager Data Management                   1
# Marketing Data Engineer                   1
# Finance Data Analyst                      1
# Name: job_title, Length: 93, dtype: int64

# %%
data[data.job_title == 'Data Analyst']
# Out:
#       work_year experience_level employment_type     job_title  salary  \
# 11         2023               SE              FT  Data Analyst  130000
# 12         2023               SE              FT  Data Analyst  100000
# 19         2023               MI              FT  Data Analyst  150000
# 20         2023               MI              FT  Data Analyst  110000
# 37         2023               MI              FT  Data Analyst  105380
# ...         ...              ...             ...           ...     ...
# 3645       2021               SE              FT  Data Analyst   90000
# 3674       2020               MI              FT  Data Analyst   85000
# 3681       2020               MI              FT  Data Analyst    8000
# 3736       2021               MI              FT  Data Analyst   75000
# 3737       2021               MI              FT  Data Analyst   62000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
data.groupby('job_title').get_group('Data Engineer')
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 31         2023               SE              FT  Data Engineer  253200
# 32         2023               SE              FT  Data Engineer   90700
# 35         2023               MI              FT  Data Engineer  162500
# 36         2023               MI              FT  Data Engineer  130000
# 44         2023               SE              FT  Data Engineer  270703
# ...         ...              ...             ...            ...     ...
# 3711       2020               MI              FT  Data Engineer  110000
# 3717       2021               SE              FT  Data Engineer   65000
# 3739       2021               MI              FT  Data Engineer   38400
# 3743       2020               MI              FT  Data Engineer  130800
# 3748       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
data.head(2)
# Out:
#    work_year experience_level employment_type                 job_title  \
# 0       2023               SE              FT  Principal Data Scientist
# 1       2023               MI              CT               ML Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   80000             EUR          85847                 ES           100
# 1   30000             USD          30000                 US           100
#
#   company_location company_size
# 0               ES            L
# 1               US            S

# %%
data[data['experience_level'] == 'SE']
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT   Principal Data Scientist
# 3          2023               SE              FT             Data Scientist
# 4          2023               SE              FT             Data Scientist
# 5          2023               SE              FT          Applied Scientist
# 6          2023               SE              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3744       2020               SE              FT  Machine Learning Engineer
# 3745       2021               SE              FT   Director of Data Science
# 3749       2021               SE              FT            Data Specialist
# 3750       2020               SE              FT             Data Scientist
# 3754       2021               SE              FT       Data Science Manager
#
# ...

# %%
#finding null values
data.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# work_year             3755
# experience_level      3755
# employment_type       3755
# job_title             3755
# salary                3755
# salary_currency       3755
# salary_in_usd         3755
# employee_residence    3755
# remote_ratio          3755
# company_location      3755
# company_size          3755
# dtype: int64

# %%
#data.head()
data.rename(columns={'salary':'salary amount'},inplace=True)
data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
data['salary amount'].mean()
# Out:
# 190695.57177097205

# %%
data['salary amount'].std()
# Out:
# 671676.5005079071

# %%
data['salary amount'].var()
# Out:
# 451149321334.5485

# %%
data['company_size'].unique()
# Out:
# array(['L', 'S', 'M'], dtype=object)

# %%
data[(data['company_size']== 'S')&(data['salary amount']>200000)]
# Out:
#       work_year experience_level employment_type  \
# 323        2022               SE              FT
# 988        2023               SE              FT
# 1512       2023               EN              FT
# 3023       2022               MI              FT
# 3075       2022               MI              FL
# 3475       2021               MI              FT
# 3476       2021               MI              FT
# 3494       2021               MI              FT
# 3593       2020               EN              FT
# 3594       2020               SE              FT
# 3609       2020               SE              FT
# 3615       2021               SE              FT
# 3640       2021               MI              FT
# 3667       2021               MI              FT
# 3675       2021               EX              CT
# 3682       2020               EN              FT
# 3699       2020               EN              FT
# 3729       2021               EN              FT
#
# ...

# %%
data.groupby('experience_level').mean('salary amount')
# Out:
#                     work_year  salary amount  salary_in_usd  remote_ratio
# experience_level
# EN                2022.053125  188381.178125   78546.284375     55.156250
# EX                2022.385965  246802.201754  194930.929825     48.245614
# MI                2022.203727  248200.306832  104525.939130     46.211180
# SE                2022.468203  170048.965421  153051.071542     45.071542

# %%
data.groupby('experience_level').min()
# Out:
#                   work_year employment_type                      job_title  \
# experience_level
# EN                     2020              CT  3D Computer Vision Researcher
# EX                     2020              CT                   AI Scientist
# MI                     2020              CT  3D Computer Vision Researcher
# SE                     2020              CT  3D Computer Vision Researcher
#
#                   salary amount salary_currency  salary_in_usd  \
# experience_level
# EN                         6000             AUD           5409
# EX                        15000             CAD          15000
# MI                         7500             AUD           5132
# SE                         8000             AUD           8000
#
#                  employee_residence  remote_ratio company_location  \
# experience_level
# EN                               AR             0               AR
# EX                               CA             0               CA
# ...

# %%
data.groupby('experience_level').max()
# Out:
#                   work_year employment_type               job_title  \
# experience_level
# EN                     2023              PT      Research Scientist
# EX                     2023              FT      Staff Data Analyst
# MI                     2023              PT  Software Data Engineer
# SE                     2023              FT    Staff Data Scientist
#
#                   salary amount salary_currency  salary_in_usd  \
# experience_level
# EN                      6600000             USD         300000
# EX                      6000000             USD         416000
# MI                     30400000             USD         450000
# SE                      7500000             USD         423834
#
#                  employee_residence  remote_ratio company_location  \
# experience_level
# EN                               VN           100               VN
# EX                               UZ           100               US
# ...

# %%
data[data['company_location'] == 'IN']
# Out:
#       work_year experience_level employment_type  \
# 41         2022               MI              FT
# 83         2022               EN              FT
# 156        2023               MI              FT
# 217        2023               EN              FT
# 735        2023               MI              FT
# 738        2023               MI              FT
# 968        2023               EN              FT
# 988        2023               SE              FT
# 1165       2023               EN              PT
# 1230       2023               EN              FT
# 1260       2023               MI              FT
# 1341       2023               EN              FT
# 1386       2022               MI              FT
# 1462       2023               MI              FT
# 1512       2023               EN              FT
# 1596       2022               MI              FT
# 1738       2021               SE              FT
# 1739       2022               MI              FT
# ...

# %%
data.head()
data[ (data['experience_level'] == 'SE')|(data['salary amount'] > 300000)]
# Out:
#       work_year experience_level employment_type  \
# 0          2023               SE              FT
# 3          2023               SE              FT
# 4          2023               SE              FT
# 5          2023               SE              FT
# 6          2023               SE              FT
# ...         ...              ...             ...
# 3745       2021               SE              FT
# 3747       2021               MI              FT
# 3749       2021               SE              FT
# 3750       2020               SE              FT
# 3754       2021               SE              FT
#
#                                job_title  salary amount salary_currency  \
# 0               Principal Data Scientist          80000             EUR
# 3                         Data Scientist         175000             USD
# 4                         Data Scientist         120000             USD
# 5                      Applied Scientist         222200             USD
# ...

# %%
data[(data['company_size']== 'S')&(data['salary amount']>200000)|(data['experience_level'] == 'MI')]
# Out:
#       work_year experience_level employment_type  \
# 1          2023               MI              CT
# 2          2023               MI              CT
# 19         2023               MI              FT
# 20         2023               MI              FT
# 35         2023               MI              FT
# ...         ...              ...             ...
# 3743       2020               MI              FT
# 3746       2021               MI              FT
# 3747       2021               MI              FT
# 3748       2021               MI              FT
# 3751       2021               MI              FT
#
#                                job_title  salary amount salary_currency  \
# 1                            ML Engineer          30000             USD
# 2                            ML Engineer          25500             USD
# 19                          Data Analyst         150000             USD
# 20                          Data Analyst         110000             USD
# ...
